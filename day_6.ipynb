# %% [markdown]
# <a href="https://colab.research.google.com/github/maggieshiro384-art/CDAV/blob/main/day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
formula=input("Type 1 kgs/height or type 2 pounds/inches" )
Height=float(input("enter your height" ))
weight=float(input("enter your weight"))
if formula=="1":
  bmi=weight/(Height*Height)
  print("your bmi is",bmi)

elif formula=="2":
  bmi=(weight/(Height*Height))*703
  print("your bmi is", bmi)
else:
  print("invalid metrics")
# Out:
# Type 1 kgs/height or type 2 pounds/inches1
# enter your height6
# enter your weight64
# your bmi is 1.7777777777777777

# %% [markdown]
# #List

# %%
#creating lists manually by defining
students=["john","mary","evans"]
print(students)
print(type(students))
# Out:
# ['john', 'mary', 'evans']
# <class 'list'>

# %%
#creating lists using typecasting
name='john'
name=list(name)
print(name)
# Out:
# ['j', 'o', 'h', 'n']

# %%
#creating a list using a split method. ,,,,, .split()
school="soma,riverdale,strathmore"
school.split(",")
# Out:
# ['soma', 'riverdale', 'strathmore']

# %%
#escape characters in string formatting
paragraph="""
this is a line
this is another line
this has a '
this has a \
"""
print(paragraph)
# Out:
# this is a line
# this is another line
# this has a '
# this has a

# %%
introduction="I am John.\nMy age is 18."
print(introduction)
# Out:
# I am John.
# My age is 18.

# %%
#when you add \t the text becomes indented

introduction="\tI am John.\n\tMy age is 18."
print(introduction)
# Out:
# 	I am John.
# 	My age is 18.

# %%
paragraph="""
this is a line
this is another line
this has a '
this has a \
"""
print(paragraph.replace("\n","\t"))
# Out:
# 	this is a line	this is another line	this has a '	this has a

# %%
# mini school data set(csv)
data="""name,gender,grade
john,m,76
james,f,82,
joseph,m,84
susan,f,72
"""
rows=data.split("\n")
print(rows[0].split(","))
# Out:
# ['name', 'gender', 'grade']

# %%
print(data.split('\n')[3].split(",")[2])
# Out:
# 84

# %%
data="""name,gender,grade
john,m,76
james,f,82,
joseph,m,84
susan,f,72
"""
rows=data.split("\n")
print(rows[0].split(","))
# Out:
# ['name', 'gender', 'grade']

# %%
cols=['name', 'gender', 'grade']
cols[::-1]
# Out:
# ['grade', 'gender', 'name']

# %%
vals=[10,20,30]
vals.append(40)
vals.insert(1,15)
avg=sum(vals)/len(vals)
print(f'the list contains{vals}.its averaga is{avg}')
# Out:
# the list contains[10, 15, 20, 30, 40].its averaga is23.0

# %%
val=[]
while user_input!="=":
  user_input=int(input("enter a number or = to stop"))
  vals.append(user_input)
  if user_input =="=":
  print(f"the sum of your numbers is{sum(val)},the minimum is{min(val)},the maximum is{max(val)}, the average is{sum(vals)/len(vals)} ")
else:
  print("user input incorrect, enter a number")
# Out:
#   File "/tmp/ipykernel_932/120873275.py", line 5
#     if user_input =="="
#                        ^
# SyntaxError: expected ':'
